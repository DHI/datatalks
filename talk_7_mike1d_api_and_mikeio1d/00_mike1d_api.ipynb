# %% [markdown]
# Presenter: *Gediminas Kišanskas* <geki@dhigroup.com> <br></br>
# Date: *2022-06-09*

# %% [markdown]
# Crash course in MIKE 1D API and mikeio1d
# ========================================
#
# 1. Use of [MIKE 1D API and C# scripts](https://github.com/DHI/Mike1D-SDK-examples/tree/master/DHI.Mike1D.Examples/Scripts) to modify a setup configuration
# <br></br>
# 2. Use of [MIKE 1D API in Python](https://github.com/DHI/Mike1D-SDK-examples/tree/master/scripts)
# <br></br>
# 3. Use of [mikeio1d](https://github.com/DHI/mikeio1d) to read res1d and xns11 files in Python

# %% [markdown]
# ## Environment:
#   * [Python 3.8.7](https://www.python.org/downloads/release/python-387/)
#   * [pythonnet 2.5.2](https://pypi.org/project/pythonnet/)
#   * [Visual Studio Code](https://code.visualstudio.com/)
#     * [.NET Interactive](https://marketplace.visualstudio.com/items?itemName=ms-dotnettools.dotnet-interactive-vscode)
#     * [Jupyter](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter)

# %% [markdown]
# ## MIKE 1D API
#
# * Edit or create setup. Everything you can do in the setup editors, you can do at runtime. Add/modify:
#   * Boundaries
#   * Catchments
#   * Nodes (manholes)
#   * Reaches (branches/links)
#   * Structures
#   * Controls
#   * etc.

# %% [markdown]
# * Extend with custom implementation:
#   * Boundaries
#   * Catchments
#   * Structures

# %% [markdown]
# * Interact with engine during simulation:
#   * Extract results
#   * Modify boundaries
#   * Perform control
#   * Inject custom functionality (headloss, infiltration in manholes, etc.)

# %%
from IPython.display import Image
Image(filename='images/mike1d_design.png')

# %% [markdown]
# Useful links:
#  * [MIKE for developers docs](https://docs.mikepoweredbydhi.com/engine_libraries/mike1d/mike1d_api/) **central place to start working with MIKE 1D API !!!**
#  * [MIKE 1D class library documentation](https://manuals.mikepoweredbydhi.help/latest/General/Class_Library/DHI_MIKE1D/html/R_Project_DHI_Mike1D.htm)
